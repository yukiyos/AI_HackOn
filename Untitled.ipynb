# %%
import os
import pandas as pd
import re
import numpy as np
import requests

# %%
def convertDataToDataframe(response,lat,long):
    data =response.json()
    lat = lat
    lon = long
    time = data['dimensions']['time']['data']
    wavedirection = data['variables']['wave.direction.mean']['data']
    windspeed = data['variables']['wind.speed.eastward.at-10m']['data']
    new_row =pd.DataFrame({
    'Latitude': lat,
    'Longitude': lon,
    'Time': time,
    'WaveDirection': wavedirection,
    'WindSpeed': windspeed
    })
    return new_row

# %%
api_URL = f"https://forecast-v2.metoceanapi.com/point/time?lat={lat}&lon={long}&variables=wave.direction.mean,wind.speed.eastward.at-10m&from=2024-08-10T02%3A54%3A15.021Z&interval=1h&repeat=24&baseModels=wave%3Aecmwf"
response = requests.get(api_URL, headers=headers)
new_df = convertDataToDataframe(response,lat,long)
df = pd.concat([df, new_df], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 response = requests.get(api_URL, headers=headers)
#       3 new_df = convertDataToDataframe(response,lat,long)
# ----> 4 df = pd.concat([df, new_df], ignore_index=True)
#
# NameError: name 'df' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 17
#      14     return None, None, None
#      16 # Iterate over each file in the folder
# ---> 17 for filename in os.listdir(folder_path):
#      18     if filename.endswith('.csv'):
#      19         # Extract region, latitude, and longitude from the filename
#      20         region, latitude, longitude = extract_info(filename)
#
# NameError: name 'os' is not defined

# %%
# Out:
#          Kaitaia Aerodrome  35.068S 173.286E 82m  NZST [UTC+12]  Dir  °T  \
# 0                                         20-Mar-2009 08:00        170.0
# 1                                         20-Mar-2009 09:00        180.0
# 2                                         20-Mar-2009 10:00        190.0
# 3                                         20-Mar-2009 11:00        180.0
# 4                                         20-Mar-2009 12:00        210.0
# ...                                                     ...          ...
# 11805300                                                NaN        170.0
# 11805301                                                NaN        180.0
# 11805302                                                NaN        200.0
# 11805303                                                NaN          NaN
# 11805304                                                NaN        150.0
#
#           Speed  kt  Max Gust Hourly kt   Vis     Weather Clouds  Temp  °C  \
# 0               3.0                 NaN   NaN         NaN    NaN      16.3
# 1               8.0                13.0   NaN         NaN    NaN      17.7
# 2              10.0                16.0   NaN         NaN    NaN      18.5
# 3              11.0                17.0   NaN         NaN    NaN      19.4
# 4              11.0                18.0   NaN         NaN    NaN      19.7
# ...             ...                 ...   ...         ...    ...       ...
# 11805300       16.0                24.0                      NaN       6.0
# 11805301       21.0                30.0                      NaN       5.0
# 11805302       12.0                26.0                      NaN       5.0
# 11805303        NaN                 NaN   NaN         NaN    NaN       NaN
# 11805304       16.0                25.0                      NaN       5.0
#
#          DewPt  °C  RH  %  ...  \
# 0             14.1   87.0  ...
# 1             13.8   78.0  ...
# 2             12.4   68.0  ...
# 3             11.5   60.0  ...
# 4             10.5   55.0  ...
# ...            ...    ...  ...
# 11805300       NaN   65.0  ...
# 11805301       NaN   74.0  ...
# 11805302       NaN   81.0  ...
# 11805303       NaN    NaN  ...
# 11805304       NaN   81.0  ...
#
#           Stephens Island  40.665S 174.000E 186m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#           Auckland Aerodrome  37.009S 174.807E 7m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#           Mahia  39.117S 177.962E 135m  NZST [UTC+12]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 11805300                                          NaN
# 11805301                                          NaN
# 11805302                                          NaN
# 11805303                                          NaN
# 11805304                                          NaN
#
#          Westport Aerodrome  41.741S 171.580E 4m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#           Milford Sound Aerodrome  44.673S 167.923E 3m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#           Tauranga Aerodrome  37.671S 176.197E 4m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#          Oamaru Aerodrome  44.972S 171.081E 30m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#          
_Jan1993_Aug2022_modified.csv
# /var/folders/x2/xkqq7vg54dsg3nwl3hpqpqcw0000gn/T/ipykernel_36789/196525343.py:24: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Processed Hourly_Taupo_Aerodrome_NZAPA_38.743S_176.081E_407m_Jan1993_Aug2022.csv -> Hourly_Taupo_Aerodrome_NZAPA_38.743S_176.081E_407m_Jan1993_Aug2022_modified.csv
# Processed Hourly_Castlepoint_NZCPX_40.904S_176.212E_118m_Jan1993_Aug2022.csv -> Hourly_Castlepoint_NZCPX_40.904S_176.212E_118m_Jan1993_Aug2022_modified.csv
# Processed Hourly_Campbell_Island_NZCAX_52.551S_169.150E_15m_Jan1993_Aug2022.csv -> Hourly_Campbell_Island_NZCAX_52.551S_169.150E_15m_Jan1993_Aug2022_modified.csv
# Processed Hourly_Invercargill_NZNVA_46.411S_168.318E_2m_Jan1993_Aug2022.csv -> Hourly_Invercargill_NZNVA_46.411S_168.318E_2m_Jan1993_Aug2022_modified.csv
# Processed Hourly_Puysegur_Point_NZPYX_46.156S_166.613E_44m_Jan1993_Aug2022.csv -> Hourly_Puysegur_Point_NZPYX_46.156S_166.613E_44m_Jan1993_Aug2022_modified.csv
# /var/folders/x2/xkqq7vg54dsg3nwl3hpqpqcw0000gn/T/ipykernel_36789/196525343.py:24: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Processed Hourly_Tauranga_Aerodrome_NZTGA_37.671S_176.197E_4m_Jan1993_Aug2022.csv -> Hourly_Tauranga_Aerodrome_NZTGA_37.671S_176.197E_4m_Jan1993_Aug2022_modified.csv
# /var/folders/x2/xkqq7vg54dsg3nwl3hpqpqcw0000gn/T/ipykernel_36789/196525343.py:24: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Processed Hourly_Whangarei_Aerodrome_NZWRA_35.767S_174.366E_41m_Jan1993_Aug2022.csv -> Hourly_Whangarei_Aerodrome_NZWRA_35.767S_174.366E_41m_Jan1993_Aug2022_modified.csv
# /var/folders/x2/xkqq7vg54dsg3nwl3hpqpqcw0000gn/T/ipykernel_36789/196525343.py:24: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Processed Hourly_Takapau_Plains_NZTKX_40.042S_176.269E_346m_Jan1993_Aug2022.csv -> Hourly_Takapau_Plains_NZTKX_40.042S_176.269E_346m_Jan1993_Aug2022_modified.csv
# /var/folders/x2/xkqq7vg54dsg3nwl3hpqpqcw0000gn/T/ipykernel_36789/196525343.py:24: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Processed Hourly_Waiouru_Aerodrome_NZRUA_39.446S_175.658E_819m_Jan1993_Aug2022.csv -> Hourly_Waiouru_Aerodrome_NZRUA_39.446S_175.658E_819m_Jan1993_Aug2022_modified.csv
# /var/folders/x2/xkqq7vg54dsg3nwl3hpqpqcw0000gn/T/ipykernel_36789/196525343.py:24: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Processed Hourly_Milford_Sound_Aerodrome_NZMFA_44.673S_167.923E_3m_Jan1993_Aug2022.csv -> Hourly_Milford_Sound_Aerodrome_NZMFA_44.673S_167.923E_3m_Jan1993_Aug2022_modified.csv
# /var/folders/x2/xkqq7vg54dsg3nwl3hpqpqcw0000gn/T/ipykernel_36789/196525343.py:24: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Processed Hourly_Timaru_Airport_NZTUA_44.305S_171.221E_27m_Jan1993_Aug2022.csv -> Hourly_Timaru_Airport_NZTUA_44.305S_171.221E_27m_Jan1993_Aug2022_modified.csv
# Processed Hourly_Kerikeri_Aerodrome_NZKKA_35.263S_173.911E_150m_Jan1993_Aug2022.csv -> Hourly_Kerikeri_Aerodrome_NZKKA_35.263S_173.911E_150m_Jan1993_Aug2022_modified.csv

# %%
# Types of rubbish, does wind speed affect what type of rubbish washes up, what weight etc denstity.
# Value proposotion
# Who would benefit from the data

# %%
start_lat = -34.163
stop_lat =  -47.44
start_long = 163
stop_long = 179.8
key = "SF6vJVhGKXmDu9TfAJQ4CH"

headers = {
    'x-api-key':  key  
}
for lat in np.arange(start_lat, stop_lat, -1.3):
    for long in np.arange(start_long, stop_long , 1.6):
        api_URL = f"https://forecast-v2.metoceanapi.com/point/time?lat={lat}&lon={long}&variables=wave.direction.mean,wind.speed.eastward.at-10m&from=2024-08-5T02%3A54%3A15.021Z&interval=1h&repeat=24&baseModels=wave%3Aecmwf"
        response = requests.get(api_URL, headers=headers)
        new_df = convertDataToDataframe(response,lat,long)
        df = pd.concat([df, new_df], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 14
#      12 api_URL = f"https://forecast-v2.metoceanapi.com/point/time?lat={lat}&lon={long}&variables=wave.direction.mean,wind.speed.eastward.at-10m&from=2024-08-5T02%3A54%3A15.021Z&interval=1h&repeat=24&baseModels=wave%3Aecmwf"
#      13 response = requests.get(api_URL, headers=headers)
# ---> 14 new_df = convertDataToDataframe(response,lat,long)
#      15 df = pd.concat([df, new_df], ignore_index=True)
#
# Cell In[2], line 5, in convertDataToDataframe(response, lat, long)
#       3 lat = lat
#       4 lon = long
# ----> 5 time = data['dimensions']['time']['data']
#       6 wavedirection = data['variables']['wave.direction.mean']['data']
#       7 windspeed = data['variables']['wind.speed.eastward.at-10m']['data']
#
# TypeError: list indices must be integers or slices, not str

# %%
start_lat = -34.163
stop_lat =  -47.44
start_long = 163
stop_long = 179.8
np.arange(start_lat, stop_lat, -1.3)
# Out:
# array([-34.163, -35.463, -36.763, -38.063, -39.363, -40.663, -41.963,
#        -43.263, -44.563, -45.863, -47.163])

# %%
combined_df = pd.concat(dataframes, ignore_index=True, axis=0)
combined_df
# Out:
#          Kaitaia Aerodrome  35.068S 173.286E 82m  NZST [UTC+12]  Dir  °T  \
# 0                                         20-Mar-2009 08:00        170.0
# 1                                         20-Mar-2009 09:00        180.0
# 2                                         20-Mar-2009 10:00        190.0
# 3                                         20-Mar-2009 11:00        180.0
# 4                                         20-Mar-2009 12:00        210.0
# ...                                                     ...          ...
# 11805300                                                NaN        170.0
# 11805301                                                NaN        180.0
# 11805302                                                NaN        200.0
# 11805303                                                NaN          NaN
# 11805304                                                NaN        150.0
#
#           Speed  kt  Max Gust Hourly kt   Vis     Weather Clouds  Temp  °C  \
# 0               3.0                 NaN   NaN         NaN    NaN      16.3
# 1               8.0                13.0   NaN         NaN    NaN      17.7
# 2              10.0                16.0   NaN         NaN    NaN      18.5
# 3              11.0                17.0   NaN         NaN    NaN      19.4
# 4              11.0                18.0   NaN         NaN    NaN      19.7
# ...             ...                 ...   ...         ...    ...       ...
# 11805300       16.0                24.0                      NaN       6.0
# 11805301       21.0                30.0                      NaN       5.0
# 11805302       12.0                26.0                      NaN       5.0
# 11805303        NaN                 NaN   NaN         NaN    NaN       NaN
# 11805304       16.0                25.0                      NaN       5.0
#
#          DewPt  °C  RH  %  ...  \
# 0             14.1   87.0  ...
# 1             13.8   78.0  ...
# 2             12.4   68.0  ...
# 3             11.5   60.0  ...
# 4             10.5   55.0  ...
# ...            ...    ...  ...
# 11805300       NaN   65.0  ...
# 11805301       NaN   74.0  ...
# 11805302       NaN   81.0  ...
# 11805303       NaN    NaN  ...
# 11805304       NaN   81.0  ...
#
#           Stephens Island  40.665S 174.000E 186m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#           Auckland Aerodrome  37.009S 174.807E 7m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#           Mahia  39.117S 177.962E 135m  NZST [UTC+12]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 11805300                                          NaN
# 11805301                                          NaN
# 11805302                                          NaN
# 11805303                                          NaN
# 11805304                                          NaN
#
#          Westport Aerodrome  41.741S 171.580E 4m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#           Milford Sound Aerodrome  44.673S 167.923E 3m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#           Tauranga Aerodrome  37.671S 176.197E 4m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#          Oamaru Aerodrome  44.972S 171.081E 30m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#          Paraparaumu Aerodrome  40.905S 174.985E 6m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#          Kerikeri Aerodrome  35.263S 173.911E 150m  NZST [UTC+12]  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                                NaN
# 11805301                                                NaN
# 11805302                                                NaN
# 11805303                                                NaN
# 11805304                                                NaN
#
#          South West Cape  47.277S 167.463E 103m  NZST [UTC+12]
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 11805300                                  03-Jul-1997 19:00
# 11805301                                  03-Jul-1997 20:00
# 11805302                                  03-Jul-1997 21:00
# 11805303                                  03-Jul-1997 22:00
# 11805304                                  03-Jul-1997 23:00
#
# [11805305 rows x 66 columns]
